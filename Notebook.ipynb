# %% [markdown]
# This is my first markdown

# %%
print("Welcome to the course!")
# Out:
# Welcome to the course!

# %%
# This is a comment

# %%
name = "Lungelo"

# %%
type(name)
# Out:
# str

# %%
age = 32

# %%
type(age)
# Out:
# int

# %%
height = 1.64

# %%
type(height)
# Out:
# float

# %%
is_student = False

# %%
type(is_student)
# Out:
# bool

# %%
name = 'Lungelo'

# %%
type(name)
# Out:
# str

# %%
print(name)
# Out:
# Lungelo

# %%
message = "If you like the course, please like the video and subscribe"

# %%
print(message)
# Out:
# If you like the course, please like the video and subscribe

# %%
number = 20

# %%
type(number)
# Out:
# int

# %%
print(number)
# Out:
# 20

# %%
height = 6.5

# %%
type(height)
# Out:
# float

# %%
print(height)
# Out:
# 6.5

# %%
print("Height:", height)
# Out:
# Height: 6.5

# %%
heightstring = "Height"

# %%
print(heightstring, height)
# Out:
# Height 6.5

# %%
is_python_great = True

# %%
type(is_python_great)
# Out:
# bool

# %%
print("Is Python Great?", is_python_great)
# Out:
# Is Python Great? True

# %%
name = "Clark"
age = 45
is_adult = True

# %%
snake_case = 30
CamelCase = 40

# %%
num1 = 10
num2 = 5

# %%
addition = num1 + num2

# %%
print(addition)
# Out:
# 15

# %%
print (10 + 5)
# Out:
# 15

# %%
subtraction = num1 - num2

# %%
print(subtraction)
# Out:
# 5

# %%
subtraction
# Out:
# 5

# %%
multiplication = num1 * num2

# %%
multiplication
# Out:
# 50

# %%
result_division = num1 / num2

# %%
result_division
# Out:
# 2.0

# %%
10/5
# Out:
# 2.0

# %%
exponentiation = num1 ** num2

# %%
exponentiation
# Out:
# 100000

# %%
# Paranthese - Exponents - Multiplication - Division

# Addition - Subtraction

# %%
pemdas = (num1 + 3) * num2 / 2 ** 2

# %%
pemdas
# Out:
# 16.25

# %%
total = 0

# %%
total += 5 # total = total + 5

# %%
total
# Out:
# 5

# %%
total -= 2 # total = total - 2

# %%
total
# Out:
# 3

# %%
total *= 3 # total = total * 3

# %%
total
# Out:
# 9

# %%
x = 5
y = 10

# %%
result1 = x == y # if x is equal to y

# %%
result1
# Out:
# False

# %%
result2 = x != y

# %%
result2 # if x is not equal to y
# Out:
# True

# %%
a = 15
b = 20

# %%
result1 = a < b

# %%
result1
# Out:
# True

# %%
result2 = a > b

# %%
result2
# Out:
# False

# %%
result3 = a <= b

# %%
result3
# Out:
# True

# %%
result4 = a >= b

# %%
result4
# Out:
# False

# %%
num = 25

# %%
result = 10 <= num <= 30

# %%
result
# Out:
# True

# %%
variable1 = 10
variable2 = 10

# %%
result1 = variable1 is variable2

# %%
result1
# Out:
# True

# %%
result2 = variable1 is not variable1

# %%
result2
# Out:
# False

# %%
greeting = "Hello, Python!"

# %%
len(greeting)
# Out:
# 14

# %%
greeting[0]
# Out:
# 'H'

# %%
greeting[13]
# Out:
# '!'

# %%
greeting[-1]
# Out:
# '!'

# %%
greeting[-2]
# Out:
# 'n'

# %%
greeting
# Out:
# 'Hello, Python!'

# %%
greeting[7:14]
# Out:
# 'Python!'

# %%
greeting + "Welcome !"
# Out:
# 'Hello, Python!Welcome !'

# %%
print(greeting + " " + "Welcome !" + "25")
# Out:
# Hello, Python! Welcome !25

# %%
type("25")
# Out:
# str

# %%
sentence = "Python is an amazing programming language."

# %%
sentence.upper()
# Out:
# 'PYTHON IS AN AMAZING PROGRAMMING LANGUAGE.'

# %%
sentence.lower()
# Out:
# 'python is an amazing programming language.'

# %%
sentence.find("amazing")
# Out:
# 13

# %%
sentence .replace("amazing", "powerful")
# Out:
# 'Python is an powerful programming language.'

# %%
sentence = sentence.replace("amazing", "powerful")

# %%
sentence
# Out:
# 'Python is an powerful programming language.'

# %%
sentence.count("i")
# Out:
# 2

# %%
name = "Jack"
age = 30

# %%
formatted_string = f"Hello, my name is {name} and I'm {age} years old"

# %%
formatted_string
# Out:
# "Hello, my name is Jack and I'm 30 years old"

# %%
formatted_string_2 = "Hello, my name is {} and I'm {} years old".format(name,age)

# %%
formatted_string_2
# Out:
# "Hello, my name is Jack and I'm 30 years old"

# %%
age = 25
if age >= 18:
    print("You are an adult.")
# Out:
# You are an adult.

# %%
age = 15
if age >= 18:
    print("You are an adult")
else:
    print("You are not an adult")
# Out:
# You are not an adult

# %%
temperature = 28

# %%
if temperature > 30:
    print("It is a hot day")
elif 20 <= temperature <=30:
    print("The weather is pleasant")
else:
    print("It's a cold day")
# Out:
# The weather is pleasant

# %%
is_raining = True
is_cold = False

# %%
if is_raining:
    print("Bring an umbrella")
    if is_cold:
        print("Wear a jacket too.")
else:
    print("enjoy the day!")
# Out:
# Bring an umbrella

# %%
age = 21

# %%
"You are allowed" if age >=18 else "You are not allowed"
# Out:
# 'You are allowed'

# %%
fruits = ["apple", "banana", "cherry"]

# %%
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
for number in range(1,4):
    print(f"Number: {number}")
# Out:
# Number: 1
# Number: 2
# Number: 3

# %%
count = 0

# %%
while count < 3:
    print(f"Count: {count}")
    count += 1
# Out:
# Count: 0
# Count: 1
# Count: 2

# %%
numbers = [1,2,3,4,5]
